# %% [markdown]
#                                        NETFLIX MOVIES AND TV SHOWS.🍿🍫
#
#     “Great storytelling is what makes something really global”  Ted Sarandos, chief content officer of Netflix.

# %%
from IPython.display import Image

# %%
Image(filename = "output/Wordcloud.png", width = 400, height = 200)

# %% [markdown]
# La leyenda cuenta que... a Reed Hasting se le ocurrió la creación de una empresa de envío de DVD's a domicilio al ser sancionado con una multa de 40$ por devolver tarde la película Apollo 13, alquilada en un local de Blockbuster. Este incidente dio lugar a lo que comenzó como una empresa de videoclub a distancia y que, actualmente, es una de las mayores plataformas de streaming a nivel mundial.

# %%
Image(filename = "output/plot matrix years and added content.png", width = 600, height = 400)

# %% [markdown]
# Como muestra este gráfico el crecimiento de Netflix se disparó entre finales de 2016 (año que puso en marcha su propio estudio) y principios de 2017, siendo el punto de mayor concentración de contenido añadido los últimos meses de 2019. Se puede obserbar fácilmente que el crecimiento en el ritmto de adhesión de contenido a la plataforma de streaming ha ido creciendo con los años, lo que se debe al aumento de suscripciones (demanda).

# %%
Image(filename = "output/Barchar top10 producing countries.png", width = 500, height = 300)

# %% [markdown]
# Como podemos ver el mayor productor de contenido es USA, cuestión lógica teniendo en cuenta la nacionalidad de sus fundadores: Marc Randolph y Reed Hastings.Tampoco se puede dejar de lado la cultura cinematográfica y televisiva de América y, en especial, de Hollywood, el barrio de Los Ángeles que representa a la industria del cine y de la televisión arraigada en el sur de California y conocida en todo el mundo.

# %%
Image(filename = "output/countplot for type, movie and tv show.png", width = 500, height = 300)

# %% [markdown]
# A pesar de que la popularidad de las series o 'TV Shows' ha aumentado de forma  notoria estos últimos años, la gráfica nos muestra que el contenido principal de la plataforma siguen siendo las películas. Aún así, no debemos perder de vista que en el dataset utilizado no se incluyen datos de 2020. Es probable que esta diferencia que estamos apreciando pueda haberse visto atenuada a día de hoy.

# %%
Image(filename = "output/PiePlotRatings.png", width = 600, height = 500)

# %% [markdown]
# En América el rating en función del contenido del programa es:  Little Kids: G, TV-Y, TV-G,
#                                                                 Older Kids: PG, TV-Y7, TV-Y7-FV, TV-PG,
#                                                                 Teens: PG-13, TV-14,
#                                                                 Mature:R, NC-17, TV-MA
#
# De modo que, queda demostrado que el público target de la plataforma son los adolescentes y los adultos, quienes
# suelen pasar gran parte de su tiempo libre "desconectando" delante de cualquier serie y/o película.

# %%
Image(filename = "output/listed_in plot.png", width = 900, height = 800)

# %% [markdown]
# Todo el mundo conoce los famosos documentales de Netflix, como 'The Last Dance' un documental en homenaje al
# jugador de la NBA fallecido, Michael Jordan. Este ha sido uno de los puntos fuertes de Netflix, ha ayudado a los
# espectadores a redescubrir los documentales, generalmente infravalorados debido, en gran parte, a los horarios de
# emisión de los mismos en la televisión convencional.

# %% [markdown]
# EN CONCLUSIÓN: Netflix siempre es una gran apuesta, tanto a la hora de invertir dinero, como inversor, como a la hora de invertir dinero como usuario, ya que su éxito deja claro que el contenido que ofrece es de calidad y, por tanto, que los objetivos perseguidos por la misma son los correctos, al adaptar sus servicios a las necesidades del cliente.
#
# *Siempre puede seguir analizando los datos en el archivo analysis.ipynb
